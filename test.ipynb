# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt


zeros = [1]
poles = ()

y_axis = 1

filterd_signal = signal.filtfilt(zeros, poles, y_axis)

print(filterd_signal)

# w, h = signal.freqz_zpk(zeros,poles,1)

# fig = plt.figure()
# ax1 = fig.add_subplot(1, 1, 1)
# ax1.set_title('Digital filter frequency response')

# # IMPORTANT
# ax1.plot(w, 20 * np.log10(abs(h)), 'b')
# # IMPORTANT
# ax1.set_ylabel('Amplitude [dB]', color='b')
# ax1.set_xlabel('Frequency [Hz]')
# ax1.grid(True)

# # IMPORTANT
# angles = np.unwrap(np.angle(h))
# # IMPORTANT
# Out:
# C:\Users\20115\AppData\Local\Temp\ipykernel_23044\888721283.py:15: RuntimeWarning: divide by zero encountered in log10
#   ax1.plot(w, 20 * np.log10(abs(h)), 'b')
